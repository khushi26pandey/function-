# %% [markdown]
# Theory Question
#
# Q1- What is the difference between a function and a method in Python?
#
# ans- function is a block of code that perform a task and it is defined as (def) ex- def name():   and method is a function that belongs to an object ex- a.lower(),a.upper().
#
#
# Q2- Explain the concept of function arguments and parameters in Python.
#
# Ans- parameter is variable in function and argument passes value to the function.
#
# Q3- What are the different ways to define and call a function in Python?
#
# ans- we can define a function using def keyword and call it by its name followed by parentheses.
#
# Q4-What is the purpose of the return statement in a Python function?
#
# ans- return function ends the function and return a value. def num(n): \n return n*n \n num(2)
#
#
# Q5- What are iterators in Python and how do they differ from iterables?
#
# ans - an iterator is an object representing a stream of data means return data one by one using next() and iterables are object that can be looped over ex- list, tuple
#
# Q6-. Explain the concept of generators in Python and how they are defined.
#
# ans - generators yield using (yield) and saves memory.
#
# Q7-What are the advantages of using generators over regular functions?
#
# ans- . memory efficient , lazy evaluation , suitable for large data.
#
# Q8 What is a lambda function in Python and when is it typically used?
#
# ans- lamba is small anonymous function . it is used when we need small, one lined and anonymous function.
#
# Q9-  Explain the purpose and usage of the map() function in Python.
#
# ans - it apply function to all items in an itrable.
#
# Q10- What is the difference between `map(), `reduce(), and `filter() functions in Python ?
#
# ans - map() apply function to each element. reduce() apply function cumulatively. filter() filter item based on condtion.
#
#
# Q11-Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13]
#
#
# ans

# %% [markdown]
# ![IMG_20250729_225157.jpg](data:image/jpeg;base64,...)

# %%
#Q1-Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.

# %%
def add(numbers):
  return sum (num for num in numbers if num%2 ==0)
  print(add[1,2,45,58,10])

# %%
#Q2-Create a Python function that accepts a string and returns the reverse of that string.

# %%
def rev_str(s):
  return s[::-1]
print(rev_str("khushi"))
# Out:
# ihsuhk

# %%
#Q3-Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.

# %%
def squ(l):
  return [l**2]
print(squ(2))
# Out:
# [4]

# %%
#Q4- Write a Python function that checks if a given number is prime or not from 1 to 200.

# %%
def prime(n):
  if n<2:
    return False
  for i in range(2,int(n**0.5)+1):
    if n% i==0:
      return False
  return True

print(prime(4))
# Out:
# False

# %%
#Q5- Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.

# %%
#Q6-Write a generator function in Python that yields the powers of 2 up to a given exponent.

# %%
def pow(exp):
  for i in range(exp + 1):
    yield 2**i

print(pow(45))
# Out:
# <generator object pow at 0x7f09498f3060>

# %%
#Q7- Implement a generator function that reads a file line by line and yields each line as a string.

# %%
def read(name):
  with open(name) as f:
    for line in f:
      yield line.strip()

# %%
#Q8-Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

# %%
lst=[(1,2),(8,4),(9,10)]
print(lst.sort(key=lambda x : x[1]))
# Out:
# None

# %%
#Q9Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.

# %%
temp_c=[0,20,30]
tepm_f=list(map(lambda c:  (c * 9/5) + 32,temp_c))
print(tepm_f)
# Out:
# [32.0, 68.0, 86.0]

# %%
#Q10- Create a Python program that uses `filter()` to remove all the vowels from a given string.

# %%
def vow(s):
  return ''.join(filter(lambda x: x.lower() not in "aeiou",s))

  print(vow("khushi"))

# %%
#Q11 Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:







Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
order is smaller than 100,00 €.

Write a Python program using lambda and map

# %%
orders=[[34587,"learning python,mark lutz",4,40.95],[98762,"programming python,mark lutz",5,56.80],[772266,"head first program,paul barry",3,32.95],
 [88112,"einfuhrung in pyhthon,bernd klein",3,34.99]]

   result=list(map(lambda order: (order[0],order[2]*order[3] if order[2]*order[3]>=100 else order[2]*order[3]+10),orders))
